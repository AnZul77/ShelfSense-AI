# %%
import easyocr

print("EasyOCR version:", easyocr.__version__)
# Out:
# EasyOCR version: 1.7.2

# %%
reader = easyocr.Reader(['en'])

print("EasyOCR Loaded Successfully!")
# Out:
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteEasyOCR Loaded Successfully!

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("step.jpg")

rotated = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

plt.figure(figsize=(8,4))
plt.imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
import easyocr

reader = easyocr.Reader(['en'])

result = reader.readtext(rotated)

for r in result:
    print(r[1], r[2])
# Out:
# STEPHEN KING 0.538160195134273
# OvTxIDEP 0.19600138103695888
